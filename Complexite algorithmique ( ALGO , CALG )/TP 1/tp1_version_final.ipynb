# %% [markdown]
# <h4> declaration

# %%
import time                                         # calculer le temps
import pandas as pd                              # pandas et matplotlib pour representation graphique 
import matplotlib.pyplot as plt
import math                                     # math pour calculer la racine carré

Numbers_premier=[1000003 , 2000003 , 4000037 , 8000009 , 16000057 , 32000011 , 64000031 , 128000003 , 256000001  , 512000009 , 1024000009 , 2048000011]

# %% [markdown]
# ## Algorithm 1
#
# nombre d'iteration N-2 , complexity : O(N)

# %% [markdown]
# <h4> implementation de la fonction <h4>

# %%
def estpremier( x ):
    if(x<2):
        return False
    else:
        for i in range(2,x):
            if x % i == 0:
                return False 
            
        
        return True

# %% [markdown]
# <h4> Execution de la fonction sur le tableau des nombres premiers<h4>

# %%
        
temps_exec=[]        
    
for x in Numbers_premier:
    
    debut= time.time()
    
    estpremier(x)                               # pour chaque nombre on calcul le temps avant et apres execution de la fonction 
    
    fin = time.time()
    
    temps_exec.append(fin-debut)

# %% [markdown]
# <h4> Resultat de temps de calcul pour chaque nombre et representation graphique<h4>

# %%
tableau= pd.DataFrame(zip(Numbers_premier , temps_exec) , columns= [ 'number' , 'temps(s) algo_1'])
print(tableau)
# Out:
#         number  temps(s) algo_1
# 0      1000003         0.086382
# 1      2000003         0.177470
# 2      4000037         0.353066
# 3      8000009         0.807316
# 4     16000057         1.577757
# 5     32000011         2.799739
# 6     64000031         5.188586
# 7    128000003        10.300315
# 8    256000001        20.658045
# 9    512000009        41.917098
# 10  1024000009        83.246505
# 11  2048000011       307.296164

# %%
plt.figure(figsize=(8,6))
plt.plot(tableau['number'],tableau['temps(s) algo_1'] , '.-')
plt.xlabel("number")
plt.ylabel("temps(s)")
plt.savefig("algo1_graph.png")

plt.show()

# %% [markdown]
# ## Algorithme 2
# Nombre d'itération (N-2)/2 , complexity : O(N)

# %% [markdown]
# #### Implementation de la fonction

# %%
def estpremier_algo2( x ):
    
    if(x<2):
        return False
    else:
        end = int(x/2)
        for i in range(2,end):
            if x % i == 0:
                return False 
                
            
        return True

# %% [markdown]
# #### Application de l'algorithme sur le tableu des nombres premiers

# %%
temps_exec2=[]
for x in Numbers_premier:
    
    debut= time.time()
    
    estpremier_algo2(x)
    
    fin = time.time()
    
    temps_exec2.append(fin-debut)

# %% [markdown]
# #### Resultat de temps de calcul pour chaque nombre et representation graphique

# %%
tableau2= pd.DataFrame(zip(Numbers_premier , temps_exec2) , columns= [ 'number' , 'temps(s) algo 2'] , )
print(tableau2)
# Out:
#         number  temps(s) algo 2
# 0      1000003         0.064425
# 1      2000003         0.104715
# 2      4000037         0.171242
# 3      8000009         0.337808
# 4     16000057         0.847394
# 5     32000011         1.586911
# 6     64000031         2.930380
# 7    128000003         5.391204
# 8    256000001        11.085654
# 9    512000009        22.282390
# 10  1024000009        41.651728
# 11  2048000011       157.052678

# %%
plt.figure(figsize=(8,6))
plt.plot(tableau2['number'],tableau2['temps(s) algo 2'] , '.-')
plt.xlabel("number")
plt.ylabel("temps(s)")
plt.savefig("algo2_graph.png")
plt.show()

# %% [markdown]
# ## Algorithme 3
# Parcourir jusqua √N-2 , complexity o(√N)

# %% [markdown]
# #### Implementation de la fonction

# %%
def estpremier_algo3( x ):
    
    if (x<2):
        return False
    else:
        end2 = int(math.sqrt(x))
        for i in range(2,end2):
            if x % i == 0:
                return False 
                
            
        return True

# %% [markdown]
# #### Application de l'algorithme sur le tableu des nombres premiers

# %%
temps_exec3=[]
for x in Numbers_premier:
    
    debut= time.time()
    
    estpremier_algo3(x)
    
    fin = time.time()
    
    temps_exec3.append(fin-debut)

# %% [markdown]
# #### Resultat de temps de calcul pour chaque nombre et representation graphique

# %%
tableau3= pd.DataFrame(zip(Numbers_premier , temps_exec3) , columns= [ 'number' , 'temps(s) algo 3'])
print(tableau3)
# Out:
#         number  temps(s) algo 3
# 0      1000003         0.000000
# 1      2000003         0.000000
# 2      4000037         0.000000
# 3      8000009         0.000000
# 4     16000057         0.000000
# 5     32000011         0.000000
# 6     64000031         0.001162
# 7    128000003         0.000000
# 8    256000001         0.001332
# 9    512000009         0.002426
# 10  1024000009         0.002416
# 11  2048000011         0.005614

# %%
plt.figure(figsize=(8,6))
plt.plot(tableau3['number'],tableau3['temps(s) algo 3'] , '.-')
plt.xlabel("number")
plt.ylabel("temps(s)")
plt.savefig("algo3_graph.png")
plt.show()

# %% [markdown]
# ## Algorithme 4
#
# Nombre d'itérations : √N-3 / 2 , complexity O(√N)

# %% [markdown]
# #### Implementation de la fonction

# %%
    
    
def estpremier_algo4( x ):
    if x<2:
        return False
    else:
        
        if x % 2==0  and x!=2:
            return False
        else:
            end=int(math.sqrt(x))+1
            for i in range(3,end,2):
            
                if x % i == 0:
                    return False 
                    
                
            return True

# %% [markdown]
# #### Application de l'algorithme sur le tableu des nombres premiers

# %%
temps_exec4=[]
for x in Numbers_premier:
    
    debut= time.time()
    
    estpremier_algo4(x)
    
    fin = time.time()
    
    temps_exec4.append(fin-debut)

# %% [markdown]
# #### Resultat de temps de calcul pour chaque nombre et representation graphique

# %%
tableau4= pd.DataFrame(zip(Numbers_premier , temps_exec4) , columns= [ 'number' , 'temps(s) algo 4'])
print(tableau4)
# Out:
#         number  temps(s) algo 4
# 0      1000003         0.000000
# 1      2000003         0.000000
# 2      4000037         0.000000
# 3      8000009         0.001076
# 4     16000057         0.000000
# 5     32000011         0.000000
# 6     64000031         0.000000
# 7    128000003         0.001072
# 8    256000001         0.000000
# 9    512000009         0.002177
# 10  1024000009         0.001629
# 11  2048000011         0.002218

# %%
plt.figure(figsize=(8,6))
plt.plot(tableau4['number'],tableau4['temps(s) algo 4'] , '.-')
plt.xlabel("number")
plt.ylabel("temps(s)")
plt.savefig("algo4_graph.png")
plt.show()

# %% [markdown]
# ## Comparison de Resultat experimentals

# %%
compareframe=pd.DataFrame(zip(Numbers_premier , temps_exec , temps_exec2 , temps_exec3 , temps_exec4) , columns=['number' , 'algo 1','algo 2','aglo 3','algo 4'])
print(compareframe)
plt.figure(figsize=(8,6))
plt.plot(tableau4['number'],tableau['temps(s) algo_1'] , '.-',label="algo 1")
plt.plot(tableau4['number'],tableau2['temps(s) algo 2'] , '.-',label="algo 2")
plt.plot(tableau4['number'],tableau3['temps(s) algo 3'] , '.-',label="algo 3")
plt.plot(tableau4['number'],tableau4['temps(s) algo 4'] , '.-',label="algo 4")
plt.xlabel("number")
plt.ylabel("temps(s)")
plt.legend()
plt.savefig("comparison.png")
plt.show()
# Out:
#         number      algo 1      algo 2    aglo 3    algo 4
# 0      1000003    0.086382    0.064425  0.000000  0.000000
# 1      2000003    0.177470    0.104715  0.000000  0.000000
# 2      4000037    0.353066    0.171242  0.000000  0.000000
# 3      8000009    0.807316    0.337808  0.000000  0.001076
# 4     16000057    1.577757    0.847394  0.000000  0.000000
# 5     32000011    2.799739    1.586911  0.000000  0.000000
# 6     64000031    5.188586    2.930380  0.001162  0.000000
# 7    128000003   10.300315    5.391204  0.000000  0.001072
# 8    256000001   20.658045   11.085654  0.001332  0.000000
# 9    512000009   41.917098   22.282390  0.002426  0.002177
# 10  1024000009   83.246505   41.651728  0.002416  0.001629
# 11  2048000011  307.296164  157.052678  0.005614  0.002218

# %% [markdown]
# ## Comparaison de Complexité théorique
#
# f(n) algo1 = 4N -5
# f(n) algo2 = 2N -3
# f(n) algo3 = 4√N-3
# f(n) algo4 = √N-3/2

# %%
import numpy as np
x1=np.linspace(0,10)
y1=4*x1 -5
y2 = 2*x1 -3
y3 = 4*np.sqrt(x1) -3
y4 = (np.sqrt(x1) - 3)/2
plt.plot(x1,y1 , label="algo 1")
plt.plot(x1,y2, label="algo 2")
plt.plot(x1,y3, label="algo 3")
plt.plot(x1,y4, label="algo 4")

plt.xlabel("N")
plt.ylabel("O(N)")
plt.savefig("algo4_graph_complexity.png")
